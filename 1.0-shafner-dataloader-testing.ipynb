# %%
from unet.dataloader import UrbanExtractionDataset
from pathlib import Path
import numpy as np

data_dir = Path('C:/Users/shafner/projects/urban_extraction/data/preprocessed/test_dataset/')
train_dir = data_dir / 'train'
test_dir = data_dir / 'test'

dataset = UrbanExtractionDataset(train_dir, 'S2FC', True)

index = 100

sample = dataset.__getitem__(index)
image = sample['image']
label = sample['label']
print(f'Image {index} ({type(image)})')
print(f'Shape: {image.shape}, Range: [{np.amin(image)}, {np.amax(image)}], Type: {image.dtype}')
print(f'Label {index} ({type(label)})')
print(f'Shape: {label.shape}, Range: [{np.amin(label)}, {np.amax(label)}] Type: {label.dtype}')
# Out:
# [{'sample_id': 'Beijing_2017_tile100', 'products': [], 'urban_percentage': '0.165'}, {'sample_id': 'Beijing_2017_tile102', 'products': [], 'urban_percentage': '0.408'}, {'sample_id': 'Beijing_2017_tile103', 'products': [], 'urban_percentage': '0.170'}, {'sample_id': 'Beijing_2017_tile105', 'products': [], 'urban_percentage': '0.130'}, {'sample_id': 'Beijing_2017_tile106', 'products': [], 'urban_percentage': '0.154'}, {'sample_id': 'Beijing_2017_tile107', 'products': [], 'urban_percentage': '0.167'}, {'sample_id': 'Beijing_2017_tile108', 'products': [], 'urban_percentage': '0.122'}, {'sample_id': 'Beijing_2017_tile109', 'products': [], 'urban_percentage': '0.077'}, {'sample_id': 'Beijing_2017_tile10', 'products': [], 'urban_percentage': '0.174'}, {'sample_id': 'Beijing_2017_tile110', 'products': [], 'urban_percentage': '0.088'}, {'sample_id': 'Beijing_2017_tile111', 'products': [], 'urban_percentage': '0.013'}, {'sample_id': 'Beijing_2017_tile112', 'products': [], 'urban_percentage': '0.003'}, {'sample_id': 'Beijing_2017_tile113', 'products': [], 'urban_percentage': '0.003'}, {'sample_id': 'Beijing_2017_tile115', 'products': [], 'urban_percentage': '0.012'}, {'sample_id': 'Beijing_2017_tile116', 'products': [], 'urban_percentage': '0.331'}, {'sample_id': 'Beijing_2017_tile118', 'products': [], 'urban_percentage': '0.385'}, {'sample_id': 'Beijing_2017_tile119', 'products': [], 'urban_percentage': '0.301'}, {'sample_id': 'Beijing_2017_tile11', 'products': [], 'urban_percentage': '0.133'}, {'sample_id': 'Beijing_2017_tile120', 'products': [], 'urban_percentage': '0.506'}, {'sample_id': 'Beijing_2017_tile121', 'products': [], 'urban_percentage': '0.397'}, {'sample_id': 'Beijing_2017_tile122', 'products': [], 'urban_percentage': '0.328'}, {'sample_id': 'Beijing_2017_tile124', 'products': [], 'urban_percentage': '0.218'}, {'sample_id': 'Beijing_2017_tile125', 'products': [], 'urban_percentage': '0.197'}, {'sample_id': 'Beijing_2017_tile126', 'products': [], 'urban_percentage': '0.209'}, {'sample_id': 'Beijing_2017_tile127', 'products': [], 'urban_percentage': '0.232'}, {'sample_id': 'Beijing_2017_tile128', 'products': [], 'urban_percentage': '0.161'}, {'sample_id': 'Beijing_2017_tile129', 'products': [], 'urban_percentage': '0.222'}, {'sample_id': 'Beijing_2017_tile12', 'products': [], 'urban_percentage': '0.127'}, {'sample_id': 'Beijing_2017_tile130', 'products': [], 'urban_percentage': '0.341'}, {'sample_id': 'Beijing_2017_tile131', 'products': [], 'urban_percentage': '0.191'}, {'sample_id': 'Beijing_2017_tile132', 'products': [], 'urban_percentage': '0.094'}, {'sample_id': 'Beijing_2017_tile133', 'products': [], 'urban_percentage': '0.021'}, {'sample_id': 'Beijing_2017_tile134', 'products': [], 'urban_percentage': '0.002'}, {'sample_id': 'Beijing_2017_tile135', 'products': [], 'urban_percentage': '0.003'}, {'sample_id': 'Beijing_2017_tile136', 'products': [], 'urban_percentage': '0.005'}, {'sample_id': 'Beijing_2017_tile137', 'products': [], 'urban_percentage': '0.012'}, {'sample_id': 'Beijing_2017_tile138', 'products': [], 'urban_percentage': '0.111'}, {'sample_id': 'Beijing_2017_tile139', 'products': [], 'urban_percentage': '0.192'}, {'sample_id': 'Beijing_2017_tile13', 'products': [], 'urban_percentage': '0.142'}, {'sample_id': 'Beijing_2017_tile140', 'products': [], 'urban_percentage': '0.429'}, {'sample_id': 'Beijing_2017_tile141', 'products': [], 'urban_percentage': '0.487'}, {'sample_id': 'Beijing_2017_tile142', 'products': [], 'urban_percentage': '0.715'}, {'sample_id': 'Beijing_2017_tile143', 'products': [], 'urban_percentage': '0.628'}, {'sample_id': 'Beijing_2017_tile144', 'products': [], 'urban_percentage': '0.554'}, {'sample_id': 'Beijing_2017_tile145', 'products': [], 'urban_percentage': '0.294'}, {'sample_id': 'Beijing_2017_tile146', 'products': [], 'urban_percentage': '0.329'}, {'sample_id': 'Beijing_2017_tile148', 'products': [], 'urban_percentage': '0.204'}, {'sample_id': 'Beijing_2017_tile150', 'products': [], ' ...
# dataset length 708
# Image 100 (<class 'numpy.ndarray'>)
# Shape: (1024, 1024, 3), Range: [0.1803921568627451, 1.0], Type: float64
# Label 100 (<class 'numpy.ndarray'>)
# Shape: (1024, 1024, 1), Range: [0, 1] Type: int32
